# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\MAYUR\OneDrive\Desktop\Ecommerce churn\E comm.xlsx")

# %%
df.head(5)
# Out:
#    CustomerID  Churn  Tenure    LoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1      4.0  Mobile Phone         3              6.0
# 1       50002      1      NaN         Phone         1              8.0
# 2       50003      1      NaN         Phone         1             30.0
# 3       50004      1      0.0         Phone         3             15.0
# 4       50005      1      0.0         Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# ...

# %%
df.shape
# Out:
# (5630, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   LoginDevice                  5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df.describe()
# Out:
#          CustomerID        Churn      Tenure      CityTier  WarehouseToHome  \
# count   5630.000000  5630.000000  5366.000000  5630.000000      5379.000000
# mean   52815.500000     0.168384    10.189899     1.654707        15.639896
# std     1625.385339     0.374240     8.557241     0.915389         8.531475
# min    50001.000000     0.000000     0.000000     1.000000         5.000000
# 25%    51408.250000     0.000000     2.000000     1.000000         9.000000
# 50%    52815.500000     0.000000     9.000000     1.000000        14.000000
# 75%    54222.750000     0.000000    16.000000     3.000000        20.000000
# max    55630.000000     1.000000    61.000000     3.000000       127.000000
#
#        HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# count     5375.000000               5630.000000        5630.000000
# mean         2.931535                  3.688988           3.066785
# std          0.721926                  1.023999           1.380194
# ...

# %%
df.head()
# Out:
#    CustomerID  Churn  Tenure    LoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1      4.0  Mobile Phone         3              6.0
# 1       50002      1      NaN         Phone         1              8.0
# 2       50003      1      NaN         Phone         1             30.0
# 3       50004      1      0.0         Phone         3             15.0
# 4       50005      1      0.0         Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# ...

# %%
df.value_counts('Churn')
# Out:
# Churn
# 0    4682
# 1     948
# Name: count, dtype: int64

# %%
df['Tenure '].value_counts()
# Out:
# Tenure
# 1.0     690
# 0.0     508
# 8.0     263
# 9.0     247
# 7.0     221
# 10.0    213
# 5.0     204
# 4.0     203
# 3.0     195
# 11.0    194
# 6.0     183
# 12.0    182
# 13.0    181
# 14.0    176
# 2.0     167
# 15.0    159
# 16.0    149
# 19.0    140
# 18.0    123
# 20.0    109
# 17.0    106
# 23.0     89
# 21.0     84
# 22.0     76
# 24.0     75
# 28.0     70
# 30.0     66
# 27.0     66
# 26.0     60
# 25.0     59
# 29.0     55
# 31.0     49
# 50.0      1
# 60.0      1
# 51.0      1
# 61.0      1
# Name: count, dtype: int64

# %%
df
# Out:
#       CustomerID  Churn  Tenure    LoginDevice  CityTier  WarehouseToHome  \
# 0          50001      1      4.0  Mobile Phone         3              6.0
# 1          50002      1      NaN         Phone         1              8.0
# 2          50003      1      NaN         Phone         1             30.0
# 3          50004      1      0.0         Phone         3             15.0
# 4          50005      1      0.0         Phone         1             12.0
# ...          ...    ...      ...           ...       ...              ...
# 5625       55626      0     10.0      Computer         1             30.0
# 5626       55627      0     13.0  Mobile Phone         1             13.0
# 5627       55628      0      1.0  Mobile Phone         1             11.0
# 5628       55629      0     23.0      Computer         3              9.0
# 5629       55630      0      8.0  Mobile Phone         1             15.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# ...

# %%
df = df.replace('Mobile Phone', 'Phone')

# %%
df.head()
# Out:
#    CustomerID  Churn  Tenure  LoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1      4.0       Phone         3              6.0
# 1       50002      1      NaN       Phone         1              8.0
# 2       50003      1      NaN       Phone         1             30.0
# 3       50004      1      0.0       Phone         3             15.0
# 4       50005      1      0.0       Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# ...

# %%
sns.countplot(y= df['LoginDevice'])
# Out:
# <Axes: xlabel='count', ylabel='LoginDevice'>

# %%
df.value_counts(['CityTier'])
# Out:
# CityTier
# 1           3666
# 3           1722
# 2            242
# Name: count, dtype: int64

# %%
df = df.replace({'Cash on Delivery':'COD', 'Credit Card' : 'CC'})

# %%
sns.countplot(x=  df['PreferredPaymentMode'],hue = df['Gender'])
# Out:
# <Axes: xlabel='PreferredPaymentMode', ylabel='count'>

# %%
df['PreferedOrderCat'] = df['PreferedOrderCat'].replace('Mobile', 'Phone')

# %%
sns.countplot(x = df['PreferedOrderCat'])
# Out:
# <Axes: xlabel='PreferedOrderCat', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# LoginDevice                      0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
df.shape
# Out:
# (5630, 20)

# %%
df = df.drop_duplicates()

# %%
sns.countplot(x = df['HourSpendOnApp'])
# Out:
# <Axes: xlabel='HourSpendOnApp', ylabel='count'>

# %%
(df['HourSpendOnApp'] == 0).sum()
# Out:
# np.int64(3)

# %%
df['HourSpendOnApp'] = df['HourSpendOnApp'].replace(0, np.nan)

# %%
df['HourSpendOnApp'] = df['HourSpendOnApp'].fillna( df['HourSpendOnApp'].median())

# %%
sns.countplot(x =  df['HourSpendOnApp'])
# Out:
# <Axes: xlabel='HourSpendOnApp', ylabel='count'>

# %%
(df['WarehouseToHome']==0).sum()
# Out:
# np.int64(0)

# %%
sns.countplot(y = df['WarehouseToHome'])
# Out:
# <Axes: xlabel='count', ylabel='WarehouseToHome'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   LoginDevice                  5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5630 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df['Tenure '].dtype
# Out:
# dtype('float64')

# %%
df['Tenure '] = df['Tenure '].fillna(df['Tenure '].median())

# %%
df['Tenure '] = df['Tenure '].astype(int)

# %%
df['Tenure '].values
# Out:
# array([ 4,  9,  9, ...,  1, 23,  8])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5630 non-null   int64
#  3   LoginDevice                  5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5630 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df['WarehouseToHome'] = df['WarehouseToHome'].fillna(df['WarehouseToHome'] .median())

# %%
df['WarehouseToHome'] = df['WarehouseToHome'].astype(int)

# %%
df['WarehouseToHome'] .dtype
# Out:
# dtype('int64')

# %%
df['HourSpendOnApp'].value_counts()
# Out:
# HourSpendOnApp
# 3.0    2945
# 2.0    1471
# 4.0    1176
# 1.0      35
# 5.0       3
# Name: count, dtype: int64

# %%
df['HourSpendOnApp'] = df['HourSpendOnApp'].astype(int)

# %%
df['CouponUsed'].value_counts()
# Out:
# CouponUsed
# 1.0     2105
# 2.0     1283
# 0.0     1030
# 3.0      327
# 4.0      197
# 5.0      129
# 6.0      108
# 7.0       89
# 8.0       42
# 10.0      14
# 9.0       13
# 11.0      12
# 12.0       9
# 13.0       8
# 14.0       5
# 16.0       2
# 15.0       1
# Name: count, dtype: int64

# %%
sns.countplot(x = df['CouponUsed'])
# Out:
# <Axes: xlabel='CouponUsed', ylabel='count'>

# %%
df['CouponUsed'] = df['CouponUsed'].fillna(df['CouponUsed'].median())

# %%
df['CouponUsed'] = df['CouponUsed'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5630 non-null   int64
#  3   LoginDevice                  5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5630 non-null   int64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5630 non-null   int64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df['OrderCount'].isnull().sum()
# Out:
# np.int64(258)

# %%
df['OrderCount'].value_counts().sort_index()
# Out:
# OrderCount
# 1.0     1751
# 2.0     2025
# 3.0      371
# 4.0      204
# 5.0      181
# 6.0      137
# 7.0      206
# 8.0      172
# 9.0       62
# 10.0      36
# 11.0      51
# 12.0      54
# 13.0      30
# 14.0      36
# 15.0      33
# 16.0      23
# Name: count, dtype: int64

# %%
df['OrderCount'] = df['OrderCount'].fillna(df['OrderCount'].median())

# %%
df['OrderCount'] = df['OrderCount'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5630 non-null   int64
#  3   LoginDevice                  5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5630 non-null   int64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5630 non-null   int64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df['DaySinceLastOrder'].value_counts()
# Out:
# DaySinceLastOrder
# 3.0     900
# 2.0     792
# 1.0     614
# 8.0     538
# 0.0     496
# 7.0     447
# 4.0     431
# 9.0     299
# 5.0     228
# 10.0    157
# 6.0     113
# 11.0     91
# 12.0     69
# 13.0     51
# 14.0     35
# 15.0     19
# 17.0     17
# 16.0     13
# 18.0     10
# 30.0      1
# 46.0      1
# 31.0      1
# Name: count, dtype: int64

# %%
df['DaySinceLastOrder'].value_counts().sort_index().head(20)
# Out:
# DaySinceLastOrder
# 0.0     496
# 1.0     614
# 2.0     792
# 3.0     900
# 4.0     431
# 5.0     228
# 6.0     113
# 7.0     447
# 8.0     538
# 9.0     299
# 10.0    157
# 11.0     91
# 12.0     69
# 13.0     51
# 14.0     35
# 15.0     19
# 16.0     13
# 17.0     17
# 18.0     10
# 30.0      1
# Name: count, dtype: int64

# %%
df['DaySinceLastOrder'] = df['DaySinceLastOrder'].fillna(df['DaySinceLastOrder'].median())

# %%
df['DaySinceLastOrder'] = df['DaySinceLastOrder'].astype(int)

# %%
df['CashbackAmount'].value_counts()
# Out:
# CashbackAmount
# 148.42    8
# 149.36    8
# 123.42    8
# 154.73    7
# 188.47    7
#          ..
# 232.98    1
# 159.00    1
# 173.77    1
# 287.91    1
# 173.78    1
# Name: count, Length: 2586, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5630 non-null   int64
#  3   LoginDevice                  5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5630 non-null   int64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5630 non-null   int64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
sns.countplot(x = df['Gender'],hue = df['Churn'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = df['Gender'], hue = df['Tenure '],palette = 'rainbow')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.columns
# Out:
# Index(['CustomerID', 'Churn', 'Tenure ', 'LoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %%
Numerical_columns  = ['CustomerID', 'Churn', 'Tenure ', 'CityTier',
       'WarehouseToHome', 'HourSpendOnApp',
       'NumberOfDeviceRegistered','SatisfactionScore',
      'NumberOfAddress', 'Complain',
       'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
       'DaySinceLastOrder', 'CashbackAmount']
for columns in df:
    df[columns].unique()
    print(df[columns])
# Out:
# 0       50001
# 1       50002
# 2       50003
# 3       50004
# 4       50005
#         ...
# 5625    55626
# 5626    55627
# 5627    55628
# 5628    55629
# 5629    55630
# Name: CustomerID, Length: 5630, dtype: int64
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5625    0
# 5626    0
# 5627    0
# 5628    0
# 5629    0
# Name: Churn, Length: 5630, dtype: int64
# 0        4
# 1        9
# 2        9
# 3        0
# 4        0
#         ..
# 5625    10
# 5626    13
# 5627     1
# 5628    23
# 5629     8
# Name: Tenure , Length: 5630, dtype: int64
# 0          Phone
# 1          Phone
# 2          Phone
# 3          Phone
# 4          Phone
#           ...
# 5625    Computer
# 5626       Phone
# 5627       Phone
# 5628    Computer
# 5629       Phone
# Name: LoginDevice, Length: 5630, dtype: object
# 0       3
# 1       1
# 2       1
# 3       3
# 4       1
#        ..
# 5625    1
# 5626    1
# 5627    1
# 5628    3
# 5629    1
# ...

# %%
df['LoginDevice'] = df['LoginDevice'].replace({'Computer' : 1 ,'Phone' : 0})
# Out:
# C:\Users\MAYUR\AppData\Local\Temp\ipykernel_26468\1442635717.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['LoginDevice'] = df['LoginDevice'].replace({'Computer' : 1 ,'Phone' : 0})

# %%
df['Gender'] = df['Gender'].replace({'Male' : 1 ,'Female' : 0})
# Out:
# C:\Users\MAYUR\AppData\Local\Temp\ipykernel_26468\3736609609.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender'] = df['Gender'].replace({'Male' : 1 ,'Female' : 0})

# %%
df.columns
# Out:
# Index(['CustomerID', 'Churn', 'Tenure ', 'LoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %%
plt.figure(figsize= (20,16))
plt.subplot(4,3,1)
sns.boxplot(x = 'Churn', y = 'Tenure ', data = df ) 
plt.subplot(4,3,2)
sns.boxplot(x = 'Churn', y = 'WarehouseToHome', data = df )
plt.subplot(4,3,3) 
sns.boxplot(x = 'Churn', y = 'HourSpendOnApp', data = df )
plt.subplot(4,3,4)
sns.boxplot(x = 'Churn',y = 'SatisfactionScore', data = df) 
plt.subplot(4,3,5) 
sns.boxplot(x = 'Churn',y = 'NumberOfAddress',data = df) 
plt.subplot(4,3,6)
sns.boxplot(x = 'Churn', y = 'OrderAmountHikeFromlastYear',data = df )
plt.subplot(4,3,7)
sns.boxplot(x = 'Churn',y = 'OrderCount',data = df)
plt.subplot(4,3,8)
sns.boxplot(x= 'Churn',y = 'DaySinceLastOrder',data = df)
plt.subplot(4,3,9)
sns.boxplot(x = 'Churn',y ='CashbackAmount',data = df)
plt.subplot(4,3,10)
sns.boxplot(x = 'Churn',y = 'CouponUsed',data = df)

plt.show()

# %%
df.columns
# Out:
# Index(['CustomerID', 'Churn', 'Tenure ', 'LoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %%
Categorical_columns = ['PreferredPaymentMode','PreferedOrderCat','MaritalStatus']

# %%
numerical_feature = ['Tenure ','LoginDevice', 'CityTier','WarehouseToHome','Gender','HourSpendOnApp','NumberOfDeviceRegistered', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress','Complain', 'OrderAmountHikeFromlastYear','CouponUsed','OrderCount','DaySinceLastOrder','CashbackAmount']

# %%
df = df[numerical_feature + categorical_columns + ['Churn']]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df = df[numerical_feature + categorical_columns + ['Churn']]
#       2 df
#
# NameError: name 'categorical_columns' is not defined

# %%
from sklearn.model_selection import train_test_split

# %%
def train_test_split_and_feature(df): 
    y = df['Churn']
    x = df.drop('Churn',axis = 1)
    x = pd.get_dummies(x,dtype = int)
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20,random_state = 0 ) 
    print(x.head(5))
    print(x.columns)
    features = list(x.columns)
    return x_train,x_test,y_train,y_test,features

# %%
x_train,x_test,y_train,y_test,features = train_test_split_and_feature(df)
# Out:
#    CustomerID  Tenure   LoginDevice  CityTier  WarehouseToHome  Gender  \
# 0       50001        4            0         3                6       0
# 1       50002        9            0         1                8       1
# 2       50003        9            0         1               30       1
# 3       50004        0            0         3               15       1
# 4       50005        0            0         1               12       1
#
#    HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# 0               3                         3                  2
# 1               3                         4                  3
# 2               2                         4                  3
# 3               2                         4                  5
# 4               3                         3                  5
#
#    NumberOfAddress  ...  PreferredPaymentMode_E wallet  \
# 0                9  ...                              0
# ...

# %%
x_train.head()
# Out:
#       CustomerID  Tenure   LoginDevice  CityTier  WarehouseToHome  Gender  \
# 1294       51295       15            0         1               24       1
# 3904       53905       18            0         1                9       0
# 3523       53524        1            0         1               13       1
# 2100       52101       18            0         3               17       0
# 4481       54482        5            0         3               14       1
#
#       HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# 1294               2                         3                  5
# 3904               4                         2                  1
# 3523               3                         5                  3
# 2100               2                         3                  1
# 4481               4                         4                  1
#
#       NumberOfAddress  ...  PreferredPaymentMode_E wallet  \
# 1294                7  ...                              0
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,f1_score,classification_report

# %%
def fit_and_evaluate_model(x_train,x_test,y_train,y_test,max_depth= 5,min_samples_split =0.01, max_features = 0.8,max_samples = 0.8):
    random_forest = RandomForestClassifier(random_state = 0,\
                                           max_depth= max_depth,\
                                           min_samples_split = min_samples_split,\
                                           max_features=max_features,
                                           max_samples = max_samples)
    model = random_forest.fit(x_train,y_train)
    random_forest_predict = random_forest.predict(x_test)
    random_forest_conf_matrix = confusion_matrix(y_test,random_forest_predict)
    random_forest_acc_score = accuracy_score(y_test,random_forest_predict)
    
    print("Confusion metrix")
    print(random_forest_conf_matrix)
    print("\n")
    print('Accuracy of Random Forest :', random_forest_acc_score*100)
    print(classification_report(y_test,random_forest_predict))
    return model

# %%
model = fit_and_evaluate_model(x_train,x_test,y_train,y_test)
# Out:
# Confusion metrix
# [[892  47]
#  [ 79 108]]
#
#
# Accuracy of Random Forest : 88.80994671403198
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93       939
#            1       0.70      0.58      0.63       187
#
#     accuracy                           0.89      1126
#    macro avg       0.81      0.76      0.78      1126
# weighted avg       0.88      0.89      0.88      1126

# %%
param_grid = [
    {'max_depth' : [3,5,7,10],'min_samples_split': [0.01,0.03,0.07,0.1],
    'max_features' : [0.7,0.8,0.9,1.0],
    'max_samples' : [0.7,0.8,0.9,1.0]}
]

# %%
from sklearn.model_selection import GridSearchCV
model = RandomForestClassifier()
search = GridSearchCV(estimator = model,param_grid = param_grid , cv= 5, verbose=5)
search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# [CV 1/5] END max_depth=3, max_features=0.7, max_samples=0.7, min_samples_split=0.01;, score=0.881 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=0.7, max_samples=0.7, min_samples_split=0.01;, score=0.881 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=0.7, max_samples=0.7, min_samples_split=0.01;, score=0.889 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=0.7, max_samples=0.7, min_samples_split=0.01;, score=0.871 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=0.7, max_samples=0.7, min_samples_split=0.01;, score=0.878 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=0.7, max_samples=0.7, min_samples_split=0.03;, score=0.878 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=0.7, max_samples=0.7, min_samples_split=0.03;, score=0.882 total time=   0.6s
# ...

# %%
results = pd.DataFrame(search.cv_results_)
results.sort_values('mean_test_score',inplace=True,ascending=False)
results.head()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 252       5.067679      0.088788         0.053765        0.000982
# 200       3.465302      0.051035         0.052178        0.003424
# 220       3.703784      0.132568         0.050418        0.005809
# 204       3.693652      0.031702         0.048658        0.008155
# 216       3.462872      0.111109         0.050953        0.009355
#
#      param_max_depth  param_max_features  param_max_samples  \
# 252               10                 1.0                1.0
# 200               10                 0.7                0.9
# 220               10                 0.8                1.0
# 204               10                 0.7                1.0
# 216               10                 0.8                0.9
#
#      param_min_samples_split  \
# 252                     0.01
# 200                     0.01
# 220                     0.01
# 204                     0.01
# 216                     0.01
#
# ...

# %%
result_save = pd.DataFrame(search.cv_results_)
result_save.to_csv('result_save.csv',index = False)

# %%
search.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 1.0,
#  'max_samples': 1.0,
#  'min_samples_split': 0.01}

# %% [markdown]
# # Evaluate the model with best parameters #

# %%
model = fit_and_evaluate_model(x_train,x_test,y_train,y_test,max_depth= 10,
                       min_samples_split =0.01, max_features = 0.7,max_samples = 1.0)
# Out:
# Confusion metrix
# [[897  42]
#  [ 68 119]]
#
#
# Accuracy of Random Forest : 90.23090586145648
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       939
#            1       0.74      0.64      0.68       187
#
#     accuracy                           0.90      1126
#    macro avg       0.83      0.80      0.81      1126
# weighted avg       0.90      0.90      0.90      1126

# %%
importances = pd.DataFrame(model.feature_importances_)
importances['features'] = features
importances.columns = ['importtance','feature']
importances.sort_values(by = 'importtance',ascending = True , inplace = True)

# %%
plt.barh(importances.feature,importances.importtance)
# Out:
# <BarContainer object of 29 artists>

# %%
feature_importance = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': model.feature_importances_
})

feature_importance.sort_values(
    by='Importance',
    ascending=False
).head(10)
# Out:
#                      Feature  Importance
# 1                    Tenure     0.407166
# 10                  Complain    0.105514
# 15            CashbackAmount    0.080193
# 9            NumberOfAddress    0.073392
# 14         DaySinceLastOrder    0.063481
# 4            WarehouseToHome    0.036413
# 8          SatisfactionScore    0.026312
# 0                 CustomerID    0.025638
# 28      MaritalStatus_Single    0.022912
# 7   NumberOfDeviceRegistered    0.021207

# %%
from sklearn.metrics import roc_auc_score

y_prob = model.predict_proba(x_test)[:,1]
roc_auc_score(y_test, y_prob)
# Out:
# np.float64(0.916796227640054)

# %%
import matplotlib.pyplot as plt

feature_importance.sort_values(
    by='Importance',
    ascending=False
).head(10).plot(
    x='Feature',
    y='Importance',
    kind='barh'
)

plt.show()
